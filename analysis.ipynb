# %%
import pandas as pd

# %%
dataset = pd.read_csv("after DES Supply Chain Network.csv")
dataset.count
# Out:
# array(['SOS008L02P', 'SOS005L04P', 'SOS002L09P', 'SOS001L12P',
#        'SOS500M24P', 'POV001L24P', 'POV500M24P', 'POP001L12P',
#        'POPF01L12P', 'AT5X5K', 'ATN02K12P', 'ATN01K24P', 'MAR02K12P',
#        'MAR01K24P', 'SE500G24P', 'POV005L04P', 'POV002L09P', 'POP002L09P',
#        'SOP001L12P', 'MASR025K', 'POP500M24P', 'SOS003L04P', 'SOS250M48P',
#        'POP005L04P', 'SE200G24P', 'ATWWP002K12P', 'MAHS025K'],
#       dtype=object)
